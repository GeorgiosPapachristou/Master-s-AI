# %%
#initial code
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
#reduce both iteration and learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 70
    n = len(x)
    learning_rate = 0.056

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 3.472, b 1.008, cost 89.0 iteration 0
# m 2.327808, b 0.7365120000000001, cost 10.209344 iteration 1
# m 2.684480512, b 0.879879168, cost 1.853480013823999 iteration 2
# m 2.553561120768, b 0.887347249152, cost 0.9414732711306206 iteration 3
# m 2.5814251442667517, b 0.937967820668928, cost 0.8171361570326863 iteration 4
# m 2.5579521787853534, b 0.9735565762803795, cost 0.7770797467370767 iteration 5
# m 2.55144008489159, b 1.0130463076650982, cost 0.74693878076337 iteration 6
# m 2.5396823409296783, b 1.0503012526830329, cost 0.718817338300085 iteration 7
# m 2.5298924760028156, b 1.0873342458301614, cost 0.6918446211559707 iteration 8
# m 2.5197206389684124, b 1.1235089383602372, cost 0.6658935310853272 iteration 9
# m 2.509925808470289, b 1.159049802570504, cost 0.6409168712374149 iteration 10
# m 2.500256478771204, b 1.1939011530365906, cost 0.6168771543339135 iteration 11
# m 2.4907897095047864, b 1.228098047029368, cost 0.5937391381128808 iteration 12
# ...

# %%
#increase both iteration and learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 130
    n = len(x)
    learning_rate = 1.04

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 64.48, b 18.72, cost 89.0 iteration 0
# m -1463.1552000000001, b -403.8528, cost 49081.48640000001 iteration 1
# m 34598.35724800001, b 9584.969472000002, cost 27355621.535152644 iteration 2
# m -816757.7860915203, b -226226.7962572801, cost 15246808856.062464 iteration 3
# m 19282380.048327897, b 5340912.24516895, cost 8497894350645.285 iteration 4
# m -455225703.38726866, b -126090218.00634857, cost 4736349033873088.0 iteration 5
# m 10747141414.953054, b 2976785843.3034134, cost 2.639830673932439e+18 iteration 6
# m -253722597756.90616, b -70277091121.35477, cost 1.4713244182800499e+21 iteration 7
# m 5989979487582.841, b 1659128268432.8777, cost 8.200509090237694e+23 iteration 8
# m -141413711583269.22, b -39169330532405.73, cost 4.570599692600977e+26 iteration 9
# m 3338548631964207.5, b 924724437254617.0, cost 2.547449349805991e+29 iteration 10
# m -7.881772455584562e+16, b -2.1831245855691628e+16, cost 1.419835169623882e+32 iteration 11
# ...

# %%
#reduce iteration and increase learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 70
    n = len(x)
    learning_rate = 1.04

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 64.48, b 18.72, cost 89.0 iteration 0
# m -1463.1552000000001, b -403.8528, cost 49081.48640000001 iteration 1
# m 34598.35724800001, b 9584.969472000002, cost 27355621.535152644 iteration 2
# m -816757.7860915203, b -226226.7962572801, cost 15246808856.062464 iteration 3
# m 19282380.048327897, b 5340912.24516895, cost 8497894350645.285 iteration 4
# m -455225703.38726866, b -126090218.00634857, cost 4736349033873088.0 iteration 5
# m 10747141414.953054, b 2976785843.3034134, cost 2.639830673932439e+18 iteration 6
# m -253722597756.90616, b -70277091121.35477, cost 1.4713244182800499e+21 iteration 7
# m 5989979487582.841, b 1659128268432.8777, cost 8.200509090237694e+23 iteration 8
# m -141413711583269.22, b -39169330532405.73, cost 4.570599692600977e+26 iteration 9
# m 3338548631964207.5, b 924724437254617.0, cost 2.547449349805991e+29 iteration 10
# m -7.881772455584562e+16, b -2.1831245855691628e+16, cost 1.419835169623882e+32 iteration 11
# ...

# %%
#increase iteration and reduce learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 130
    n = len(x)
    learning_rate = 0.056

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 3.472, b 1.008, cost 89.0 iteration 0
# m 2.327808, b 0.7365120000000001, cost 10.209344 iteration 1
# m 2.684480512, b 0.879879168, cost 1.853480013823999 iteration 2
# m 2.553561120768, b 0.887347249152, cost 0.9414732711306206 iteration 3
# m 2.5814251442667517, b 0.937967820668928, cost 0.8171361570326863 iteration 4
# m 2.5579521787853534, b 0.9735565762803795, cost 0.7770797467370767 iteration 5
# m 2.55144008489159, b 1.0130463076650982, cost 0.74693878076337 iteration 6
# m 2.5396823409296783, b 1.0503012526830329, cost 0.718817338300085 iteration 7
# m 2.5298924760028156, b 1.0873342458301614, cost 0.6918446211559707 iteration 8
# m 2.5197206389684124, b 1.1235089383602372, cost 0.6658935310853272 iteration 9
# m 2.509925808470289, b 1.159049802570504, cost 0.6409168712374149 iteration 10
# m 2.500256478771204, b 1.1939011530365906, cost 0.6168771543339135 iteration 11
# m 2.4907897095047864, b 1.228098047029368, cost 0.5937391381128808 iteration 12
# ...

# %%
#increase iteration by 30% and keep stable the learning rate
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 130
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
#reduce iteration by 30% and keep stable learning rate
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 70
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
#keep stable iteration and increase learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n = len(x)
    learning_rate = 1.04

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 64.48, b 18.72, cost 89.0 iteration 0
# m -1463.1552000000001, b -403.8528, cost 49081.48640000001 iteration 1
# m 34598.35724800001, b 9584.969472000002, cost 27355621.535152644 iteration 2
# m -816757.7860915203, b -226226.7962572801, cost 15246808856.062464 iteration 3
# m 19282380.048327897, b 5340912.24516895, cost 8497894350645.285 iteration 4
# m -455225703.38726866, b -126090218.00634857, cost 4736349033873088.0 iteration 5
# m 10747141414.953054, b 2976785843.3034134, cost 2.639830673932439e+18 iteration 6
# m -253722597756.90616, b -70277091121.35477, cost 1.4713244182800499e+21 iteration 7
# m 5989979487582.841, b 1659128268432.8777, cost 8.200509090237694e+23 iteration 8
# m -141413711583269.22, b -39169330532405.73, cost 4.570599692600977e+26 iteration 9
# m 3338548631964207.5, b 924724437254617.0, cost 2.547449349805991e+29 iteration 10
# m -7.881772455584562e+16, b -2.1831245855691628e+16, cost 1.419835169623882e+32 iteration 11
# ...

# %%
#keep stable iteration and decrease learning rate by 30%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n = len(x)
    learning_rate = 0.056

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 3.472, b 1.008, cost 89.0 iteration 0
# m 2.327808, b 0.7365120000000001, cost 10.209344 iteration 1
# m 2.684480512, b 0.879879168, cost 1.853480013823999 iteration 2
# m 2.553561120768, b 0.887347249152, cost 0.9414732711306206 iteration 3
# m 2.5814251442667517, b 0.937967820668928, cost 0.8171361570326863 iteration 4
# m 2.5579521787853534, b 0.9735565762803795, cost 0.7770797467370767 iteration 5
# m 2.55144008489159, b 1.0130463076650982, cost 0.74693878076337 iteration 6
# m 2.5396823409296783, b 1.0503012526830329, cost 0.718817338300085 iteration 7
# m 2.5298924760028156, b 1.0873342458301614, cost 0.6918446211559707 iteration 8
# m 2.5197206389684124, b 1.1235089383602372, cost 0.6658935310853272 iteration 9
# m 2.509925808470289, b 1.159049802570504, cost 0.6409168712374149 iteration 10
# m 2.500256478771204, b 1.1939011530365906, cost 0.6168771543339135 iteration 11
# m 2.4907897095047864, b 1.228098047029368, cost 0.5937391381128808 iteration 12
# ...
